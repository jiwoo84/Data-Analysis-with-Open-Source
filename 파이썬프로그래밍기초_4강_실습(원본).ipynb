# %% [markdown]
# <a href="https://colab.research.google.com/github/jiwoo84/Data-Analysis-with-Open-Source/blob/main/%ED%8C%8C%EC%9D%B4%EC%8D%AC%ED%94%84%EB%A1%9C%EA%B7%B8%EB%9E%98%EB%B0%8D%EA%B8%B0%EC%B4%88_4%EA%B0%95_%EC%8B%A4%EC%8A%B5(%EC%9B%90%EB%B3%B8).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 4강 2절

# %% [markdown]
# ## 별 삼각형 출력하기

# %%
print("*")
# Out:
# *

# %% [markdown]
# ## 원뿔의 부피&겉넓이 계산 프로그램 5

# %%
rad = input("반지름을 입력하세요: ")
print(rad)
# Out:
# 10
# 10

# %%
# 원뿔 부피 및 겉넓이 계산 프로그램
rad = input("반지름을 입력하세요: ")
hei = input("높이를 입력하세요: ")
sla = pow(rad ** 2 + hei ** 2, 0.5)
#부피 & 겉넓이 출력
print(1 / 3 * 3.14 * rad ** 2 * hei )
print(3.14 * rad ** 2 + 3.14 * rad * sla)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_143/3329012316.py in <cell line: 0>()
#       1 # 원뿔 부피 및 겉넓이 계산 프로그램
# ----> 2 rad = input("반지름을 입력하세요: ")
#       3 hei = input("높이를 입력하세요: ")
#       4 sla = pow(rad ** 2 + hei ** 2, 0.5)
#       5 #부피 & 겉넓이 출력
#
# /usr/local/lib/python3.12/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#    1175                 "raw_input was called, but this frontend does not support input requests."
#    1176             )
# -> 1177         return self._input_request(
#    1178             str(prompt),
#    1179             self._parent_ident["shell"],
#
# /usr/local/lib/python3.12/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#    1217             except KeyboardInterrupt:
#    1218                 # re-raise KeyboardInterrupt, to truncate traceback
# -> 1219                 raise KeyboardInterrupt("Interrupted by user") from None
#    1220             except Exception:
#    1221                 self.log.warning("Invalid Message:", exc_info=True)
#
# KeyboardInterrupt: Interrupted by user
